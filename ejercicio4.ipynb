# %%
import pandas as pd
datos = pd.read_csv('./clima-sps.csv')
datos = datos.dropna()
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 488 entries, 0 to 732
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              488 non-null    object
#  1   datetime          488 non-null    object
#  2   tempmax           488 non-null    float64
#  3   tempmin           488 non-null    float64
#  4   temp              488 non-null    float64
#  5   feelslikemax      488 non-null    float64
#  6   feelslikemin      488 non-null    float64
#  7   feelslike         488 non-null    float64
#  8   dew               488 non-null    float64
#  9   humidity          488 non-null    float64
#  10  precip            488 non-null    float64
#  11  precipprob        488 non-null    int64
#  12  precipcover       488 non-null    float64
#  13  preciptype        488 non-null    object
#  14  snow              488 non-null    int64
#  15  snowdepth         488 non-null    int64
#  16  windgust          488 non-null    float64
#  17  windspeed         488 non-null    float64
#  18  winddir           488 non-null    float64
#  19  sealevelpressure  488 non-null    float64
#  20  cloudcover        488 non-null    float64
#  21  visibility        488 non-null    float64
#  22  solarradiation    488 non-null    float64
#  23  solarenergy       488 non-null    float64
#  24  uvindex           488 non-null    int64
#  25  severerisk        488 non-null    int64
#  26  sunrise           488 non-null    object
#  27  sunset            488 non-null    object
#  28  moonphase         488 non-null    float64
#  29  conditions        488 non-null    object
#  30  description       488 non-null    object
#  31  icon              488 non-null    object
#  32  stations          488 non-null    object
# dtypes: float64(19), int64(5), object(9)
# memory usage: 129.6+ KB

# %%
datos = datos.drop('name', axis=1)
datos = datos.drop('stations', axis=1)
datos = datos.drop('icon', axis=1)
datos = datos.drop('description', axis=1)
datos = datos.drop('snow', axis=1)
datos = datos.drop('snowdepth', axis=1)

# datos = datos.drop('conditions', axis=1)
datos = datos.drop('sunrise', axis=1)
datos = datos.drop('sunset', axis=1)
datos = datos.drop('datetime', axis=1)

# datos['preciptype'].value_counts()
# dummies = pd.get_dummies(datos['preciptype'], dtype=int)
# datos = pd.concat([datos, dummies], axis=1)
datos = datos.drop('preciptype', axis=1)

datos['conditions'].value_counts()
dummies = pd.get_dummies(datos['conditions'], dtype=int)
datos = pd.concat([datos, dummies], axis=1)
datos = datos.drop('conditions', axis=1)

datos.hist(bins=50, figsize=(20,15), edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'tempmax'}>,
#         <Axes: title={'center': 'tempmin'}>,
#         <Axes: title={'center': 'temp'}>,
#         <Axes: title={'center': 'feelslikemax'}>,
#         <Axes: title={'center': 'feelslikemin'}>],
#        [<Axes: title={'center': 'feelslike'}>,
#         <Axes: title={'center': 'dew'}>,
#         <Axes: title={'center': 'humidity'}>,
#         <Axes: title={'center': 'precip'}>,
#         <Axes: title={'center': 'precipprob'}>],
#        [<Axes: title={'center': 'precipcover'}>,
#         <Axes: title={'center': 'windgust'}>,
#         <Axes: title={'center': 'windspeed'}>,
#         <Axes: title={'center': 'winddir'}>,
#         <Axes: title={'center': 'sealevelpressure'}>],
#        [<Axes: title={'center': 'cloudcover'}>,
#         <Axes: title={'center': 'visibility'}>,
#         <Axes: title={'center': 'solarradiation'}>,
#         <Axes: title={'center': 'solarenergy'}>,
#         <Axes: title={'center': 'uvindex'}>],
#        [<Axes: title={'center': 'severerisk'}>,
#         <Axes: title={'center': 'moonphase'}>,
#         <Axes: title={'center': 'rain'}>,
#         <Axes: title={'center': 'Partially cloudy'}>,
#         <Axes: title={'center': 'Rain, Overcast'}>],
#        [<Axes: title={'center': 'Rain, Partially cloudy'}>, <Axes: >,
#         <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
import seaborn as sb

sb.set(rc={'figure.figsize':(15,8)})
sb.heatmap(data=datos.corr('spearman'), annot=True, cmap='YlGnBu' )
# Out:
# <Axes: >
