# %%
#clusterizacion K-Means
import pandas as pd
datos = pd.read_csv('./housing.csv')

X = datos.loc[:, ['latitude', 'longitude', 'median_income']]
X
# Out:
#        latitude  longitude  median_income
# 0         37.88    -122.23         8.3252
# 1         37.86    -122.22         8.3014
# 2         37.85    -122.24         7.2574
# 3         37.85    -122.25         5.6431
# 4         37.85    -122.25         3.8462
# ...         ...        ...            ...
# 20635     39.48    -121.09         1.5603
# 20636     39.49    -121.21         2.5568
# 20637     39.43    -121.22         1.7000
# 20638     39.43    -121.32         1.8672
# 20639     39.37    -121.24         2.3886
#
# [20640 rows x 3 columns]

# %%
import seaborn as sb

sb.scatterplot(data=X, x='longitude', y="latitude", hue="median_income", palette='coolwarm')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=6)

predicciones = model.fit_predict(X)

X['cluster'] = predicciones
X
# Out:
#        latitude  longitude  median_income  cluster
# 0         37.88    -122.23         8.3252        2
# 1         37.86    -122.22         8.3014        2
# 2         37.85    -122.24         7.2574        2
# 3         37.85    -122.25         5.6431        2
# 4         37.85    -122.25         3.8462        0
# ...         ...        ...            ...      ...
# 20635     39.48    -121.09         1.5603        0
# 20636     39.49    -121.21         2.5568        0
# 20637     39.43    -121.22         1.7000        0
# 20638     39.43    -121.32         1.8672        0
# 20639     39.37    -121.24         2.3886        0
#
# [20640 rows x 4 columns]

# %%
sb.scatterplot(data=X, x='longitude', y="latitude", hue="cluster", palette='coolwarm')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
X.groupby("cluster").mean()
# Out:
#           latitude   longitude  median_income
# cluster
# 0        38.357825 -121.890843       2.810203
# 1        33.815840 -117.819897       2.800254
# 2        37.709105 -121.968736       5.495516
# 3        33.859036 -118.023232       5.335464
# 4        36.113830 -119.729762       2.660959
# 5        34.853771 -119.181914      10.572799

# %%
X["cluster"].hist(bins=50, figsize=(20,15), edgecolor='black')
# Out:
# <Axes: >
